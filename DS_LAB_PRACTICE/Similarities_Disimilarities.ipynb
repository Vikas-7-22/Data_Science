# %%
import pandas as pd
import numpy as np
from scipy.spatial import distance

pointA = np.array([2,3,4])
pointB = np.array([5,6,7])

euclidean_distance = distance.euclidean(pointA, pointB)
print(f"Euclidean distance: {euclidean_distance}")
manhattan_distance = distance.cityblock(pointA, pointB)
print(f"Manhattan distance: {manhattan_distance}")
minkowski_distance = distance.minkowski(pointA, pointB, p=3)
print(f"Minkowski distance: {minkowski_distance}")
minkowski_distance = distance.minkowski(pointA, pointB, p=1)
print(f"Minkowski distance(p1): {minkowski_distance}")
similarity_distance = 1/(1+euclidean_distance)
print(f"Similarity distance: {similarity_distance}")
# Out:
# Euclidean distance: 5.196152422706632
# Manhattan distance: 9
# Minkowski distance: 4.3267487109222245
# Minkowski distance(p1): 9.0
# Similarity distance: 0.16139047779640892

# %%
df=pd.DataFrame({
    'X':[10,20,30,40,50],
    'Y':[12,24,33,45,60]
})
corr_matrix=df.corr(method='pearson')
print("Pearson Correlation Matrix:\n",corr_matrix)
# Out:
# Pearson Correlation Matrix:
#            X         Y
# X  1.000000  0.996403
# Y  0.996403  1.000000

# %%
import pandas as pd
from scipy.stats import spearmanr
df=pd.DataFrame({
    'X':[10,20,30,40,50],
    'Y':[12,24,33,45,60]
})
corr_value,p_value=spearmanr(df['X'],df['Y'])
print("Spearman Correlation Coefficient:",corr_value)
print("p-value:",p_value)
# Out:
# Spearman Correlation Coefficient: 0.9999999999999999
# p-value: 1.4042654220543672e-24

# %%
def hamming_distance(str1,str2):
  if(len(str1)!=len(str2)):
    raise ValueError('Strings must be of equal length')
  return sum(ch1!=ch2 for ch1,ch2 in zip(str1,str2))
s1='hello'
s2='world'
distance=hamming_distance(s1,s2)
print(f"Hamming Distance between '{s1}'and'{s2}': {distance}")
# Out:
# Hamming Distance between 'hello'and'world': 4

# %%
def jaccard_similarity(str1,str2):
  set1,set2=set((str1).split()),set((str2).split())
  intersection=len(set1.intersection(set2))
  union=len(set1.union(set2))
  return (intersection)/(union)
s1="data science is fun"
s2="science makes data useful"
print("Jaccard Index:",jaccard_similarity(s1,s2))
# Out:
# Jaccard Index: 0.3333333333333333

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
s1="data science is fun"
s2="science makes data useful"
vectorizer=CountVectorizer().fit([s1,s2])
vectors=vectorizer.transform([s1,s2])
cos_sin=cosine_similarity(vectors[0],vectors[1])[0][0]
print("Cosine Similarity:",cos_sin)
# Out:
# Cosine Similarity: 0.5

# %%
def lcs_length(X,Y):
  m,n=len(X),len(Y)
  dp=[[0]*(n+1) for _ in range(m+1)]
  for i in range(m):
    for j in range(n):
      if X[i]==Y[j]:
        dp[i+1][j+1]=dp[i][j]+1
      else:
        dp[i+1][j+1]=max(dp[i][j+1],dp[i+1][j])
  return dp[m][n]
seq1="ABCDEF"
seq2="AEBDF"
length=lcs_length(seq1,seq2)
print(f"Largest Common Subsequence length between '{seq1}' and '{seq2}' :{length}")
# Out:
# Largest Common Subsequence length between 'ABCDEF' and 'AEBDF' :4
