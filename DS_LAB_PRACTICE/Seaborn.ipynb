# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("temporal.csv")
sns.lineplot(x="Mes",y="data science",data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
sns.countplot(x="data science",data=df,palette="Set1")
plt.show()
# Out:
# /tmp/ipykernel_2131/4034996149.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="data science",data=df,palette="Set1")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("darkgrid")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("whitegrid")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("white")
sns.despine()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("white")
sns.despine(left=True)
plt.show()

# %%
import seaborn
import  matplotlib.pyplot as plt
df=sns.load_dataset("tips")
sns.pairplot(df,hue='day')
plt.show()

# %%
import seaborn
import  matplotlib.pyplot as plt
df=sns.load_dataset("iris")
sns.pairplot(df,hue='species')
plt.show()

# %%
import seaborn
import  matplotlib.pyplot as plt
df=sns.load_dataset("tips")
custom_palette={'Male':'Red','Female':'Green'}
sns.pairplot(df,hue='sex',palette=custom_palette)
plt.show()

# %%
import seaborn
import  matplotlib.pyplot as plt
df=sns.load_dataset("tips")
sns.pairplot(df[['total_bill','tip','size']])
plt.show()
#

# %%
import seaborn
import  matplotlib.pyplot as plt
df=sns.load_dataset("tips")
sns.pairplot(df[['total_bill','tip',]])
plt.show()
#

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
x=np.random.randn(200)
y=np.random.randn(100)
sns.kdeplot(x)
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
x=np.random.randn(200)
x=np.random.randn(100)
sns.kdeplot(y,shade=True)
plt.show()
# Out:
# /tmp/ipykernel_2131/1928727687.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(y,shade=True)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
x=np.random.randn(200)
x=np.random.randn(100)
sns.kdeplot(x=x,y=y,shade=True)
plt.show()
# Out:
# /tmp/ipykernel_2131/325558773.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=x,y=y,shade=True)

# %%
import seaborn
import  matplotlib.pyplot as plt
df=sns.load_dataset("iris")
sns.kdeplot(x=df['petal_length'])
plt.show()

# %%
import seaborn
import  matplotlib.pyplot as plt
df=sns.load_dataset("iris")
sns.kdeplot(x=df['petal_length'],y=df['petal_width'])
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset('iris')
sns.set_style('white')
sns.jointplot(x='sepal_length',y='sepal_width',data=df)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset('tips')
sns.countplot(y='sex',hue='smoker',data=df)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('Iris (1).csv') # Corrected filename to include space
import numpy as np
plt.boxplot(df['SepalWidthCm']) # Corrected column access
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(1,100,(10,10))
sns.heatmap(data,vmin=30,vmax=70)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(1,100,(10,10))
sns.heatmap(data,cmap='tab20')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(1,100,(10,10))
sns.heatmap(data,cmap='coolwarm',center=50)
plt.show()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('tips.csv')

sns.heatmap(df[['total_bill']])
plt.show()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=[12,15,20,22,23,25,25,25,30,32,35,40]
plt.hist(data,bins=5,color='maroon',edgecolor='black')
plt.xlabel('X')
plt.ylabel("Y")
plt.title("Histogram")
plt.show()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("tips.csv")
data=df[["total_bill"]]
plt.hist(data,bins=5,color='maroon',edgecolor='black')
plt.xlabel('X')
plt.ylabel("Y")
plt.title("Histogram")
plt.show()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("tips.csv")
plt.violinplot(df['total_bill'])
plt.show()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
df=sns.load_dataset("iris")
sns.violinplot(x='species',y='petal_length',data=df)
plt.title("violin plot")
plt.show()

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
print("First 5 rows of datasets:")
print(df.head())
skewness_values=df.skew()
print("\nskewness values:")
print(skewness_values)
kurtosis_values=df.kurt()
print("\nkurtosis values:")
print(kurtosis_values)
# Out:
# First 5 rows of datasets:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# skewness values:
# sepal length (cm)    0.314911
# sepal width (cm)     0.318966
# petal length (cm)   -0.274884
# petal width (cm)    -0.102967
# dtype: float64
#
# kurtosis values:
# sepal length (cm)   -0.552064
# sepal width (cm)     0.228249
# petal length (cm)   -1.402103
# petal width (cm)    -1.340604
# dtype: float64
